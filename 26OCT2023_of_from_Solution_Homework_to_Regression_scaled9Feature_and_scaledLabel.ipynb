# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/Data-Analytics-using-Python/blob/main/26OCT2023_of_from_Solution_Homework_to_Regression_scaled9Feature_and_scaledLabel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
! wget https://storage.googleapis.com/1sep/2008.csv
# Out:
# --2023-10-26 13:47:34--  https://storage.googleapis.com/1sep/2008.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.145.207, 74.125.128.207, 173.194.69.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.145.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689413344 (657M) [text/csv]
# Saving to: ‘2008.csv.1’
#
# 2008.csv.1          100%[===================>] 657.48M  36.0MB/s    in 19s
#
# 2023-10-26 13:47:54 (34.1 MB/s) - ‘2008.csv.1’ saved [689413344/689413344]

# %%
! wc -l 2008.csv
# Out:
# 7009729 2008.csv

# %%
import pandas as pd
import random

f = "2008.csv"
num_lines = sum(1 for l in open(f))
size = int(num_lines / 100)

# ตั้งค่า seed สำหรับการสุ่ม
random.seed(42)  # คุณสามารถเปลี่ยนเลข 42 เป็นเลขอื่น ๆ ได้

skip_idx = random.sample(range(1, num_lines), num_lines - size)
raw_pd = pd.read_csv(f, skiprows=skip_idx)

# %%
#raw_pd = pd.read_csv("2008.csv")

# %%
raw_pd.head(5)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   1416.0        1325   1512.0
# 1  2008      1           3          4   1312.0        1300   1546.0
# 2  2008      1           3          4   2321.0        1955     38.0
# 3  2008      1           3          4   2105.0        2045   2234.0
# 4  2008      1           3          4   1103.0        1100   1337.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1435            WN         54  ...    2.0      5.0          0
# 1        1550            WN       1397  ...    7.0      7.0          0
# 2        2115            WN        593  ...    6.0      6.0          0
# 3        2225            WN       3046  ...    4.0     14.0          0
# 4        1330            WN       2784  ...    5.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0               NaN         0          12.0          0.0      0.0
# 1               NaN         0           NaN          NaN      NaN
# 2               NaN         0           0.0          0.0    203.0
# 3               NaN         0           NaN          NaN      NaN
# 4               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            0.0               25.0
# 1            NaN                NaN
# 2            0.0                0.0
# 3            NaN                NaN
# 4            NaN                NaN
#
# [5 rows x 29 columns]

# %%
raw_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70096 entries, 0 to 70095
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               70096 non-null  int64
#  1   Month              70096 non-null  int64
#  2   DayofMonth         70096 non-null  int64
#  3   DayOfWeek          70096 non-null  int64
#  4   DepTime            68718 non-null  float64
#  5   CRSDepTime         70096 non-null  int64
#  6   ArrTime            68562 non-null  float64
#  7   CRSArrTime         70096 non-null  int64
#  8   UniqueCarrier      70096 non-null  object
#  9   FlightNum          70096 non-null  int64
#  10  TailNum            69233 non-null  object
#  11  ActualElapsedTime  68524 non-null  float64
#  12  CRSElapsedTime     70089 non-null  float64
#  13  AirTime            68524 non-null  float64
#  14  ArrDelay           68524 non-null  float64
#  15  DepDelay           68718 non-null  float64
#  16  Origin             70096 non-null  object
#  17  Dest               70096 non-null  object
#  18  Distance           70096 non-null  int64
#  19  TaxiIn             68562 non-null  float64
#  20  TaxiOut            68711 non-null  float64
#  21  Cancelled          70096 non-null  int64
#  22  CancellationCode   1390 non-null   object
#  23  Diverted           70096 non-null  int64
#  24  CarrierDelay       15150 non-null  float64
#  25  WeatherDelay       15150 non-null  float64
#  26  NASDelay           15150 non-null  float64
#  27  SecurityDelay      15150 non-null  float64
#  28  LateAircraftDelay  15150 non-null  float64
# dtypes: float64(14), int64(10), object(5)
# memory usage: 15.5+ MB

# %%
raw_pd.describe().transpose()
# Out:
#                      count         mean          std     min     25%     50%  \
# Year               70096.0  2008.000000     0.000000  2008.0  2008.0  2008.0
# Month              70096.0     6.385172     3.424041     1.0     3.0     6.0
# DayofMonth         70096.0    15.734764     8.780945     1.0     8.0    16.0
# DayOfWeek          70096.0     3.927328     1.986393     1.0     2.0     4.0
# DepTime            68718.0  1333.663261   477.444316     1.0   929.0  1325.0
# CRSDepTime         70096.0  1326.515008   463.385759     1.0   929.0  1320.0
# ArrTime            68562.0  1482.436423   503.777855     1.0  1108.0  1513.0
# CRSArrTime         70096.0  1495.090305   481.933020     1.0  1115.0  1517.0
# FlightNum          70096.0  2219.922849  1958.481821     1.0   622.0  1568.0
# ActualElapsedTime  68524.0   126.923764    69.959489    14.0    77.0   109.0
# CRSElapsedTime     70089.0   128.535162    69.094874   -12.0    80.0   110.0
# AirTime            68524.0   103.732692    67.199121    10.0    55.0    86.0
# ArrDelay           68524.0     8.020927    38.194390   -81.0   -10.0    -2.0
# DepDelay           68718.0     9.945735    34.962445   -59.0    -4.0    -1.0
# Distance           70096.0   723.418369   559.495451    31.0   325.0   580.0
# TaxiIn             68562.0     6.880284     5.054729     0.0     4.0     6.0
# TaxiOut            68711.0    16.314346    11.099367     0.0    10.0    14.0
# Cancelled          70096.0     0.019830     0.139417     0.0     0.0     0.0
# Diverted           70096.0     0.002596     0.050889     0.0     0.0     0.0
# CarrierDelay       15150.0    16.144158    39.760064     0.0     0.0     0.0
# WeatherDelay       15150.0     2.948779    19.970825     0.0     0.0     0.0
# NASDelay           15150.0    17.092673    32.803636     0.0     0.0     6.0
# SecurityDelay      15150.0     0.060132     1.632405     0.0     0.0     0.0
# LateAircraftDelay  15150.0    20.317096    38.084356     0.0     0.0     0.0
#
#                       75%     max
# Year               2008.0  2008.0
# Month                 9.0    12.0
# DayofMonth           23.0    31.0
# DayOfWeek             6.0     7.0
# DepTime            1728.0  2400.0
# CRSDepTime         1715.0  2359.0
# ArrTime            1910.0  2400.0
# CRSArrTime         1907.0  2400.0
# FlightNum          3508.0  7829.0
# ActualElapsedTime   156.0   772.0
# CRSElapsedTime      158.0   660.0
# AirTime             132.0   753.0
# ArrDelay             11.0  1312.0
# DepDelay              8.0  1153.0
# Distance            948.0  4962.0
# TaxiIn                8.0   308.0
# TaxiOut              19.0   312.0
# Cancelled             0.0     1.0
# Diverted              0.0     1.0
# CarrierDelay         17.0   875.0
# WeatherDelay          0.0  1153.0
# NASDelay             21.0   533.0
# SecurityDelay         0.0   121.0
# LateAircraftDelay    25.0   473.0

# %%
## เตรียมข้อมูลสำหรับการวิเคราะห์หา C.V.

describe_pd = pd.DataFrame(raw_pd.describe().transpose())

describe_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, Year to LateAircraftDelay
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   24 non-null     float64
#  1   mean    24 non-null     float64
#  2   std     24 non-null     float64
#  3   min     24 non-null     float64
#  4   25%     24 non-null     float64
#  5   50%     24 non-null     float64
#  6   75%     24 non-null     float64
#  7   max     24 non-null     float64
# dtypes: float64(8)
# memory usage: 2.2+ KB

# %%
## ดู Dispersion จาก C.V.

#describe_pd['std'].apply(lambda x: x/100)
describe_pd.assign(cv=lambda x: ((100/x['mean'])*x['std']))[['mean','std','cv']]
#df.assign(Discount_Percent=lambda x: (100/x.Fee)*x.Discount)
# Out:
#                           mean          std           cv
# Year               2008.000000     0.000000     0.000000
# Month                 6.385172     3.424041    53.624884
# DayofMonth           15.734764     8.780945    55.806018
# DayOfWeek             3.927328     1.986393    50.578733
# DepTime            1333.663261   477.444316    35.799465
# CRSDepTime         1326.515008   463.385759    34.932568
# ArrTime            1482.436423   503.777855    33.983100
# CRSArrTime         1495.090305   481.933020    32.234375
# FlightNum          2219.922849  1958.481821    88.222968
# ActualElapsedTime   126.923764    69.959489    55.119299
# CRSElapsedTime      128.535162    69.094874    53.755620
# AirTime             103.732692    67.199121    64.781044
# ArrDelay              8.020927    38.194390   476.184239
# DepDelay              9.945735    34.962445   351.532051
# Distance            723.418369   559.495451    77.340509
# TaxiIn                6.880284     5.054729    73.466876
# TaxiOut              16.314346    11.099367    68.034399
# Cancelled             0.019830     0.139417   703.061037
# Diverted              0.002596     0.050889  1959.970248
# CarrierDelay         16.144158    39.760064   246.281430
# WeatherDelay          2.948779    19.970825   677.257476
# NASDelay             17.092673    32.803636   191.916359
# SecurityDelay         0.060132     1.632405  2714.701430
# LateAircraftDelay    20.317096    38.084356   187.449803

# %%
categorical = list(raw_pd.select_dtypes('object').columns)
print(f"Categorical columns are: {categorical}")

numerical = list(raw_pd.select_dtypes('number').columns)
print(f"Numerical columns are: {numerical}")
# Out:
# Categorical columns are: ['UniqueCarrier', 'TailNum', 'Origin', 'Dest', 'CancellationCode']
# Numerical columns are: ['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime', 'CRSArrTime', 'FlightNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled', 'Diverted', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']

# %%
## Feature Engineering, Model Training and Evaluation

# %%
def t_timeperiod(origin):
    if origin is None:
        period = None
    elif origin > 0 and origin < 600:
        period = '00.01-05.59'
    elif origin >= 600 and origin <=1200:
        period = '06.00-11.59'
    elif origin >= 1200 and origin <= 1800:
        period = '12.00-17.59'
    elif origin >= 1800 and origin <= 2400:
        period = '18.00-24.00'
    else:
        period = 'NA'
    return period

# %%
raw_pd['DepTime'] = raw_pd['DepTime'].apply(lambda x:t_timeperiod(x))

# %%
max_distance = raw_pd['Distance'].max()
min_distance = raw_pd['Distance'].min()

# %%
max_ArrDelay = raw_pd['ArrDelay'].max()
min_ArrDelay = raw_pd['ArrDelay'].min()

# %%
def t_normalized_distance(origin):
    if origin is None:
        return None
    else:
        return ((origin-min_distance)/(max_distance-min_distance))

# %%
def t_normalized_ArrDelay(origin):
    if origin is None:
        return None
    else:
        return ((origin-min_ArrDelay)/(max_ArrDelay-min_ArrDelay))

# %%
raw_pd['Distance'] = raw_pd['Distance'].apply(lambda x:t_normalized_distance(x))

# %%
raw_pd['ArrDelay'] = raw_pd['ArrDelay'].apply(lambda x:t_normalized_ArrDelay(x))

# %%
features_pd = raw_pd[['UniqueCarrier','Origin','Dest',\
        'DepTime','TaxiOut','TaxiIn','DepDelay',\
        'DayOfWeek','Distance','ArrDelay']]

# %%
final_pd = features_pd.dropna()

# %%
final_pd.count()
# Out:
# UniqueCarrier    68524
# Origin           68524
# Dest             68524
# DepTime          68524
# TaxiOut          68524
# TaxiIn           68524
# DepDelay         68524
# DayOfWeek        68524
# Distance         68524
# ArrDelay         68524
# dtype: int64

# %%
features_pd.head(20)
# Out:
#    UniqueCarrier Origin Dest      DepTime  TaxiOut  TaxiIn  DepDelay  \
# 0             WN    ISP  BWI  12.00-17.59      5.0     2.0      51.0
# 1             WN    ISP  MCO  12.00-17.59      7.0     7.0      12.0
# 2             WN    LAX  SFO  18.00-24.00      6.0     6.0     206.0
# 3             WN    MCO  HOU  18.00-24.00     14.0     4.0      20.0
# 4             WN    MCO  ISP  06.00-11.59     10.0     5.0       3.0
# 5             WN    MDW  BNA           NA      NaN     NaN       NaN
# 6             WN    OKC  HOU  06.00-11.59      9.0     3.0       0.0
# 7             WN    PDX  PHX  06.00-11.59      7.0     7.0      14.0
# 8             WN    PVD  TPA  12.00-17.59      9.0     5.0      23.0
# 9             WN    SEA  LAS  12.00-17.59     20.0     5.0      11.0
# 10            WN    SMF  PHX  18.00-24.00      8.0     5.0      26.0
# 11            WN    SNA  PHX  12.00-17.59     11.0     3.0       6.0
# 12            WN    STL  LIT  18.00-24.00     10.0     4.0      51.0
# 13            WN    BHM  SDF  18.00-24.00      6.0     4.0       0.0
# 14            WN    BUF  BWI  12.00-17.59      8.0     4.0       5.0
# 15            WN    BUR  OAK  12.00-17.59     13.0    13.0     149.0
# 16            WN    BUR  OAK  18.00-24.00     10.0    21.0      10.0
# 17            WN    BWI  SAT  06.00-11.59     10.0     2.0      13.0
# 18            WN    CMH  MCO  12.00-17.59     11.0     6.0       0.0
# 19            WN    CMH  MDW  06.00-11.59     10.0     6.0       8.0
#
#     DayOfWeek  Distance  ArrDelay
# 0           4  0.038329  0.084709
# 1           4  0.190834  0.055276
# 2           4  0.062056  0.203877
# 3           4  0.165686  0.064609
# 4           4  0.190834  0.063173
# 5           4  0.073819       NaN
# 6           4  0.078686  0.055994
# 7           4  0.198337  0.068916
# 8           4  0.224295  0.057430
# 9           4  0.169337  0.075377
# 10          4  0.124924  0.073223
# 11          4  0.062259  0.056712
# 12          4  0.053742  0.091170
# 13          5  0.059217  0.052405
# 14          5  0.050700  0.058866
# 15          5  0.059623  0.175879
# 16          5  0.059623  0.073223
# 17          5  0.279051  0.045226
# 18          5  0.156358  0.050969
# 19          5  0.051308  0.061019

# %%
#raw_pd.isnull().sum()
#nullCol_series = raw_pd.isnull().sum()
#notNull_list = list(nullCol_series[nullCol_series == 0].index)
#notNull_list
#requiredCol_list = ['TaxiIn','TaxiOut','ArrDelay']
#selectedCol_list = notNull_list + requiredCol_list
#noNull_pd = raw_pd.loc[:,selectedCol_list].dropna()
#noNull_pd.isnull().sum()
#noNull_pd.describe()
#noNull_pd.info()

# %%
#final_pd = noNull_pd

# %%
import pandas as pd
from seaborn import load_dataset
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

# %%
train_df = final_pd.sample(frac=0.8,random_state=123)

# %%
test_df = final_pd.drop(train_df.index)

# %%
train_df.count()
# Out:
# UniqueCarrier    54819
# Origin           54819
# Dest             54819
# DepTime          54819
# TaxiOut          54819
# TaxiIn           54819
# DepDelay         54819
# DayOfWeek        54819
# Distance         54819
# ArrDelay         54819
# dtype: int64

# %%
test_df.count()
# Out:
# UniqueCarrier    13705
# Origin           13705
# Dest             13705
# DepTime          13705
# TaxiOut          13705
# TaxiIn           13705
# DepDelay         13705
# DayOfWeek        13705
# Distance         13705
# ArrDelay         13705
# dtype: int64

# %%
train_labels = train_df.filter(['ArrDelay'])
train_df = train_df.loc[:, train_df.columns != 'ArrDelay']

# %%
type(train_labels)
# Out:
# pandas.core.frame.DataFrame

# %%
test_labels = test_df.filter(['ArrDelay'])
test_df = test_df.loc[:, test_df.columns != 'ArrDelay']

# %%
X_train = train_df
X_test = test_df
y_train = train_labels
y_test = test_labels

# %%
categorical = list(X_train.select_dtypes('object').columns)
print(f"Categorical columns are: {categorical}")

numerical = list(X_train.select_dtypes('number').columns)
print(f"Numerical columns are: {numerical}")
# Out:
# Categorical columns are: ['UniqueCarrier', 'Origin', 'Dest', 'DepTime']
# Numerical columns are: ['TaxiOut', 'TaxiIn', 'DepDelay', 'DayOfWeek', 'Distance']

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz, DecisionTreeRegressor
from sklearn import tree
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# Define custom transformer
class ColumnSelector(BaseEstimator, TransformerMixin):
    """Select only specified columns."""
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X[self.columns]

# Define categorical pipeline
cat_pipe = Pipeline([('selector', ColumnSelector(categorical)),
                     ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
                     ('encoder', OneHotEncoder(handle_unknown='ignore', sparse=False))])

# Define numerical pipeline
num_pipe = Pipeline([('selector', ColumnSelector(numerical))
                     #('imputer', SimpleImputer(strategy='median')),
                     #('scaler', MinMaxScaler())
                    ])

# Combine categorical and numerical pipeline
preprocessor = FeatureUnion(transformer_list=[('cat', cat_pipe),
                                              ('num', num_pipe)])

# Model Training
pipe = Pipeline(steps=[('preprocessor', preprocessor),
              ('model', LinearRegression())])
pipeline_model = pipe.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

predictions = pipeline_model.predict(X_test)
print("\t RMSE:", mean_squared_error(y_test, predictions, squared=False))
print("\t R2 score:", r2_score(y_test, predictions))
# Out:
# 	 RMSE: 0.006548276343484768
# 	 R2 score: 0.9510334718872948
