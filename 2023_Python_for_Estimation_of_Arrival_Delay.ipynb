# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/Data-Analytics-using-Python/blob/main/2023_Python_for_Estimation_of_Arrival_Delay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## นำเข้าข้อมูล

#! wget https://storage.googleapis.com/1sep/2008.csv

# %%
## นับจำนวน row ข้อมูลด้วยคำสั่ง linux

! wc -l 2008.csv
# Out:
# 7009729 2008.csv

# %%
## สุ่มเลือกข้อมูลมาเพียง 1% และใช้ pd อ่านมาเป็น pandas dataframe คือ raw_pd

f = "2008.csv"
num_lines = sum(1 for l in open(f))
size = int(num_lines / 100)
import random
skip_idx = random.sample(range(1, num_lines), num_lines - size)
raw_pd = pd.read_csv(f, skiprows=skip_idx)

# %%
raw_pd.info()

## นับจำนวน row ที่อ่านได้ในแต่ละ col. (non-null) เปรียบเทียบกับผลจาก wc -l
## แปรผลได้ว่า หลายๆ col. มี null แฝงอยู่ ** CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay มี null แฝงอยู่เท่ากัน **
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70096 entries, 0 to 70095
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               70096 non-null  int64
#  1   Month              70096 non-null  int64
#  2   DayofMonth         70096 non-null  int64
#  3   DayOfWeek          70096 non-null  int64
#  4   DepTime            68699 non-null  float64
#  5   CRSDepTime         70096 non-null  int64
#  6   ArrTime            68536 non-null  float64
#  7   CRSArrTime         70096 non-null  int64
#  8   UniqueCarrier      70096 non-null  object
#  9   FlightNum          70096 non-null  int64
#  10  TailNum            69204 non-null  object
#  11  ActualElapsedTime  68509 non-null  float64
#  12  CRSElapsedTime     70087 non-null  float64
#  13  AirTime            68509 non-null  float64
#  14  ArrDelay           68509 non-null  float64
#  15  DepDelay           68699 non-null  float64
# ...

# %% [markdown]
# # ** CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay มี null แฝงอยู่เท่ากัน ** ทำไมจึงเป็นเช่นนั้น ดูการพิสูจน์ด้านล่าง **

# %%
raw_pd[['LateAircraftDelay']]
# Out:
#        LateAircraftDelay
# 0                    NaN
# 1                   12.0
# 2                    3.0
# 3                   15.0
# 4                    0.0
# ...                  ...
# 70091                NaN
# 70092                NaN
# 70093                NaN
# 70094                NaN
# 70095                NaN
#
# [70096 rows x 1 columns]

# %%
raw_pd['LateAircraftDelay']
# Out:
# 0         NaN
# 1        12.0
# 2         3.0
# 3        15.0
# 4         0.0
#          ...
# 70091     NaN
# 70092     NaN
# 70093     NaN
# 70094     NaN
# 70095     NaN
# Name: LateAircraftDelay, Length: 70096, dtype: float64

# %%
nullLateAircraftDelay_df = raw_pd[raw_pd['LateAircraftDelay'].isnull()]
nullLateAircraftDelay_df.describe().transpose()


## เห็นว่า LateAircraftDelay เป็น null แล้ว CarrierDelay, WeatherDelay, NASDelay, SecurityDelay จะเป็น null เสมอ
# Out:
#                      count         mean          std     min     25%     50%  \
# Year               54829.0  2008.000000     0.000000  2008.0  2008.0  2008.0
# Month              54829.0     6.467946     3.376350     1.0     4.0     7.0
# DayofMonth         54829.0    15.690219     8.810033     1.0     8.0    16.0
# DayOfWeek          54829.0     3.911124     1.984730     1.0     2.0     4.0
# DepTime            53432.0  1284.223331   469.369821     1.0   858.0  1245.0
# CRSDepTime         54829.0  1291.386930   466.044686     5.0   900.0  1248.0
# ArrTime            53269.0  1449.877415   480.477336     1.0  1046.0  1434.0
# CRSArrTime         54829.0  1460.600467   480.989498     1.0  1053.0  1440.0
# FlightNum          54829.0  2211.006967  1953.295942     1.0   612.0  1567.0
# ActualElapsedTime  53242.0   122.379343    67.652941    19.0    74.0   105.0
# CRSElapsedTime     54820.0   126.807990    68.846428    24.0    78.0   109.0
# ...

# %%
raw_pd[~(raw_pd['LateAircraftDelay'].isnull())].describe().transpose()
# Out:
#                      count         mean          std     min     25%     50%  \
# Year               15267.0  2008.000000     0.000000  2008.0  2008.0  2008.0
# Month              15267.0     6.068579     3.514239     1.0     3.0     6.0
# DayofMonth         15267.0    15.557542     8.828876     1.0     8.0    16.0
# DayOfWeek          15267.0     3.956573     1.977540     1.0     2.0     4.0
# DepTime            15267.0  1508.131133   472.307693     1.0  1145.0  1548.0
# CRSDepTime         15267.0  1450.902600   440.107543    15.0  1110.5  1505.0
# ArrTime            15267.0  1598.850658   570.112072     1.0  1254.0  1714.0
# CRSArrTime         15267.0  1621.842602   471.415426     1.0  1259.0  1700.0
# FlightNum          15267.0  2246.071854  1997.521119     1.0   627.0  1567.0
# ActualElapsedTime  15267.0   143.686055    77.308501    25.0    87.5   126.0
# CRSElapsedTime     15267.0   135.669156    72.812504    15.0    83.0   118.0
# ...

# %%
## ทำ subdata อ้างอิง row label index เพื่อให้เห็นว่า ไม่มีการบันทึก Delay 5 ประเภท เมื่อ ArrDelay ต่ำกว่า 15
raw_pd[(raw_pd['LateAircraftDelay'].isnull())].describe().transpose()['ArrDelay':'ArrDelay']
# Out:
#             count      mean        std   min   25%  50%  75%   max
# ArrDelay  53242.0 -5.694527  10.039266 -68.0 -12.0 -6.0  1.0  14.0

# %%
raw_pd[~(raw_pd['LateAircraftDelay'].isnull())].describe().transpose()['ArrDelay':'ArrDelay']
# Out:
#             count       mean       std   min   25%   50%   75%     max
# ArrDelay  15267.0  56.567892  57.45083  15.0  23.0  37.0  69.0  1060.0

# %% [markdown]
# ** สิ้นสุดการพิสูจน์ **

# %%
raw_pd.describe().transpose()
# Out:
#                      count         mean          std     min     25%     50%  \
# Year               70096.0  2008.000000     0.000000  2008.0  2008.0  2008.0
# Month              70096.0     6.380963     3.410818     1.0     3.0     6.0
# DayofMonth         70096.0    15.661322     8.814248     1.0     8.0    16.0
# DayOfWeek          70096.0     3.921023     1.983241     1.0     2.0     4.0
# DepTime            68699.0  1333.982431   479.150504     1.0   927.0  1326.0
# CRSDepTime         70096.0  1326.129651   465.199788     5.0   925.0  1320.0
# ArrTime            68536.0  1483.062522   505.641748     1.0  1107.0  1513.0
# CRSArrTime         70096.0  1495.719214   483.519450     1.0  1115.0  1518.0
# FlightNum          70096.0  2218.644145  1963.052111     1.0   615.0  1567.0
# ActualElapsedTime  68509.0   127.127472    70.479614    19.0    77.0   109.0
# CRSElapsedTime     70087.0   128.738211    69.824911    15.0    80.0   110.0
# ...

# %% [markdown]
# # ** อยากรู้ว่าอะไรมีความสัมพันธ์กับ ArrDelay **

# %%
raw_pd[['Month','ArrDelay']]

## แปรผลได้ว่า ข้อมูลมี 7x,xxx แจกแจงออกมา 12 เดือน ทำให้ว่าในแต่ละเดือน มีจำนวน flight ที่พอๆ กัน

## แปรผลได้ว่า ยังไม่เห็นว่าเดือนไหน สัมพันธ์กับ ArrDelay
# Out:
#        Month  ArrDelay
# 0          1     -14.0
# 1          1      72.0
# 2          1      21.0
# 3          1      28.0
# 4          1      19.0
# ...      ...       ...
# 70091     12       9.0
# 70092     12     -21.0
# 70093     12     -16.0
# 70094     12     -13.0
# 70095     12     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_10, *['Month'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# ...

# %%
raw_pd[['DayofMonth','ArrDelay']]

## แปรผลได้ว่า flight เยอะทุกๆ 5 วันของเดือน

## แปรผลได้ว่า ยังไม่เห็นว่าวันไหนของเดือน สัมพันธ์กับ ArrDelay
# Out:
#        DayofMonth  ArrDelay
# 0               3     -14.0
# 1               3      72.0
# 2               3      21.0
# 3               3      28.0
# 4               3      19.0
# ...           ...       ...
# 70091          13       9.0
# 70092          13     -21.0
# 70093          13     -16.0
# 70094          13     -13.0
# 70095          13     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_49, *['DayofMonth'], **{})
# chart
# ...

# %%
raw_pd[['DayOfWeek','ArrDelay']]

## แปรผลได้ว่า ข้อมูลมี 7x,xxx แจกแจงออกมา 7 วัน ทำให้ว่าในแต่ละวันของสัปดาห์ มีจำนวน flight ที่พอๆ กัน

## แปรผลได้ว่า ยังไม่เห็นว่าวันไหนของสัปดาห์ สัมพันธ์กับ ArrDelay
# Out:
#        DayOfWeek  ArrDelay
# 0              4     -14.0
# 1              4      72.0
# 2              4      21.0
# 3              4      28.0
# 4              4      19.0
# ...          ...       ...
# 70091          6       9.0
# 70092          6     -21.0
# 70093          6     -16.0
# 70094          6     -13.0
# 70095          6     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_54, *['DayOfWeek'], **{})
# chart
# import numpy as np
# ...

# %%
# Select columns ending with "Delay"
colDelay_list = [col for col in raw_pd.columns if col.endswith('Delay')&(col != 'ArrDelay')]

colDelay_list
# Out:
# ['DepDelay',
#  'CarrierDelay',
#  'WeatherDelay',
#  'NASDelay',
#  'SecurityDelay',
#  'LateAircraftDelay']

# %%
raw_pd[['LateAircraftDelay']+['ArrDelay']]

## แปรผลได้ว่า LateAircraftDelay สัมพันธ์กับ ArrDelay ในแบบ (Simple) Linear อยู่ค่อนข้างมาก
# Out:
#        LateAircraftDelay  ArrDelay
# 0                    NaN     -14.0
# 1                   12.0      72.0
# 2                    3.0      21.0
# 3                   15.0      28.0
# 4                    0.0      19.0
# ...                  ...       ...
# 70091                NaN       9.0
# 70092                NaN     -21.0
# 70093                NaN     -16.0
# 70094                NaN     -13.0
# 70095                NaN     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
# ...

# %%
raw_pd[['SecurityDelay']+['ArrDelay']]

## แปรผลได้ว่า ยังไม่เห็นว่า SecurityDelay มีสัมพันธ์กับ ArrDelay
# Out:
#        SecurityDelay  ArrDelay
# 0                NaN     -14.0
# 1                0.0      72.0
# 2                0.0      21.0
# 3                0.0      28.0
# 4                0.0      19.0
# ...              ...       ...
# 70091            NaN       9.0
# 70092            NaN     -21.0
# 70093            NaN     -16.0
# 70094            NaN     -13.0
# 70095            NaN     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
raw_pd[['NASDelay']+['ArrDelay']]

## แปรผลได้ว่า NASDelay สัมพันธ์กับ ArrDelay ในแบบ (Simple) Linear อยู่ด้วย
# Out:
#        NASDelay  ArrDelay
# 0           NaN     -14.0
# 1           0.0      72.0
# 2           0.0      21.0
# 3           4.0      28.0
# 4           0.0      19.0
# ...         ...       ...
# 70091       NaN       9.0
# 70092       NaN     -21.0
# 70093       NaN     -16.0
# 70094       NaN     -13.0
# 70095       NaN     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_255, *['NASDelay'], **{})
# chart
# import numpy as np
# ...

# %%
raw_pd[['WeatherDelay']+['ArrDelay']]

## แปรผลได้ว่า WeatherDelay สัมพันธ์กับ ArrDelay ในแบบ (Simple) Linear อยู่ด้วย
# Out:
#        WeatherDelay  ArrDelay
# 0               NaN     -14.0
# 1               0.0      72.0
# 2               0.0      21.0
# 3               0.0      28.0
# 4               0.0      19.0
# ...             ...       ...
# 70091           NaN       9.0
# 70092           NaN     -21.0
# 70093           NaN     -16.0
# 70094           NaN     -13.0
# 70095           NaN     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
raw_pd[['CarrierDelay']+['ArrDelay']]

## แปรผลได้ว่า NASDelay สัมพันธ์กับ ArrDelay ในแบบ (Simple) Linear อยู่ค่อนข้างมาก
# Out:
#        CarrierDelay  ArrDelay
# 0               NaN     -14.0
# 1              60.0      72.0
# 2              18.0      21.0
# 3               9.0      28.0
# 4              19.0      19.0
# ...             ...       ...
# 70091           NaN       9.0
# 70092           NaN     -21.0
# 70093           NaN     -16.0
# 70094           NaN     -13.0
# 70095           NaN     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
raw_pd[['DepDelay']+['ArrDelay']]

## แปรผลได้ว่า DepDelay สัมพันธ์กับ ArrDelay ในแบบ (Simple) Linear อย่างชัดเจน
# Out:
#        DepDelay  ArrDelay
# 0           1.0     -14.0
# 1          87.0      72.0
# 2          42.0      21.0
# 3          24.0      28.0
# 4          19.0      19.0
# ...         ...       ...
# 70091      -5.0       9.0
# 70092      -2.0     -21.0
# 70093       1.0     -16.0
# 70094      -6.0     -13.0
# 70095       0.0     -10.0
#
# [70096 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_270, *['DepDelay'], **{})
# chart
# import numpy as np
# ...

# %%
raw_pd[['DepDelay']+['ArrDelay']][raw_pd['ArrDelay']>=400] ##แม้ว่าจะเป็นช่วง oulier ของ ArrDelay ก็ยังคงพบความสัมพันธ์ฯ
# Out:
#        DepDelay  ArrDelay
# 4491      679.0     663.0
# 5503      590.0     631.0
# 6964      403.0     410.0
# 9851      785.0     759.0
# 9956      476.0     585.0
# 13770     996.0     990.0
# 15237     480.0     480.0
# 16176     452.0     466.0
# 16706    1030.0    1004.0
# 16713     527.0     547.0
# 16841     371.0     446.0
# 17587     294.0     438.0
# 17624     457.0     529.0
# 22103     487.0     533.0
# 22259    1057.0    1060.0
# 27637     -14.0     823.0
# 29644     669.0     674.0
# 29855     478.0     475.0
# 29902     519.0     543.0
# 33759     521.0     542.0
# 33993     414.0     416.0
# 34091     814.0     792.0
# 34486     812.0     811.0
# 36655     406.0     411.0
# 36782     580.0     552.0
# 40351     418.0     412.0
# 41612     327.0     656.0
# 44004     427.0     445.0
# 46828     504.0     490.0
# 52011     671.0     688.0
# 52101     524.0     512.0
# 53690     610.0     621.0
# 62851     885.0     878.0
# 63208     428.0     420.0
# ...

# %% [markdown]
# # ** จบการค้นพบความสัมพันธ์ระหว่าง col. ต่างๆ กับ ArrDelay **

# %%
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4491   2008      1           3          4   1959.0         840   2131.0
# 5503   2008      1          11          5   1550.0         600   1806.0
# 6964   2008      2          22          5   1558.0         915   1702.0
# 9851   2008      2          13          3   2035.0         730   2234.0
# 9956   2008      2          11          1   1606.0         810   1930.0
# 13770  2008      3          21          5   2236.0         600     15.0
# 15237  2008      3          30          7   1440.0         640   1714.0
# 16176  2008      3          28          5   1811.0        1039   2040.0
# 16706  2008      3           8          6    705.0        1355    939.0
# 16713  2008      3          16          7   2252.0        1405    257.0
# 16841  2008      3           8          6   1811.0        1200   2236.0
# 17587  2008      3          18          2   1759.0        1305   2122.0
# ...

# %%
raw_pd[raw_pd['ArrDelay']>=15]
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1      2008      1           3          4   2057.0        1930    202.0
# 2      2008      1           3          4   1127.0        1045   1856.0
# 3      2008      1           3          4   1134.0        1110   1343.0
# 4      2008      1           3          4   1409.0        1350   1539.0
# 7      2008      1           3          4   1419.0        1400   1534.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 70071  2008     12          11          4   1303.0        1203   1404.0
# 70073  2008     12          12          5   1854.0        1855   2206.0
# 70078  2008     12          12          5   1303.0        1200   1537.0
# 70085  2008     12          12          5   2153.0        2136   2219.0
# 70089  2008     12          13          6   1358.0        1325   1536.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
raw_pd[raw_pd['ArrDelay']>=400]

## เราเห็น pattern ของเดือน 3, 10
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4491   2008      1           3          4   1959.0         840   2131.0
# 5503   2008      1          11          5   1550.0         600   1806.0
# 6964   2008      2          22          5   1558.0         915   1702.0
# 9851   2008      2          13          3   2035.0         730   2234.0
# 9956   2008      2          11          1   1606.0         810   1930.0
# 13770  2008      3          21          5   2236.0         600     15.0
# 15237  2008      3          30          7   1440.0         640   1714.0
# 16176  2008      3          28          5   1811.0        1039   2040.0
# 16706  2008      3           8          6    705.0        1355    939.0
# 16713  2008      3          16          7   2252.0        1405    257.0
# 16841  2008      3           8          6   1811.0        1200   2236.0
# 17587  2008      3          18          2   1759.0        1305   2122.0
# ...

# %%
## ArrDelay >=400 เฉพาะเดือน 10 นั่นไม่มีเลย

raw_pd[(raw_pd['ArrDelay']>=400)&(raw_pd['Month']==10)]
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %%
## ArrDelay >=400 เฉพาะเดือน 3

raw_pd[(raw_pd['ArrDelay']>=400)&(raw_pd['Month']==3)].describe().transpose()['ArrDelay':'ArrDelay']
# Out:
#           count   mean         std    min    25%    50%     75%     max
# ArrDelay    8.0  612.5  240.306947  438.0  461.0  504.5  657.75  1004.0

# %%
raw_pd[raw_pd['ArrDelay']>=300][['Month','ArrDelay']]
# Out:
#        Month  ArrDelay
# 1748       1     305.0
# 3017       1     346.0
# 3102       1     364.0
# 3248       1     313.0
# 3354       1     322.0
# ...      ...       ...
# 66253     12     370.0
# 68325     12     374.0
# 68557     12     348.0
# 68919     12     349.0
# 69011     12     328.0
#
# [108 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_59, *['Month'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# ...
