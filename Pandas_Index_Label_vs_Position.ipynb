# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/Data-Analytics-using-Python/blob/main/Pandas_Index_Label_vs_Position.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
## กรณีไม่กำหนด Index Label
noIndexLabel_pd = pd.DataFrame({'Province':['กาญจนบุรี','เพชรบุรี','ราชบุรี'],'amount':[80,40,0]})

# %%
noIndexLabel_pd

## สังเกตว่า ได้รับ Index Label ที่ตรงกับ Index Position
# Out:
#     Province  amount
# 0  กาญจนบุรี      80
# 1   เพชรบุรี      40
# 2    ราชบุรี       0

# %%
# ตรวจสอบ index labels
print("Index Labels:", noIndexLabel_pd.index)

# ตรวจสอบ index positions
print("Index Positions:", range(len(noIndexLabel_pd)))
# Out:
# Index Labels: RangeIndex(start=0, stop=3, step=1)
# Index Positions: range(0, 3)

# %%
noIndexLabel_pd[1:]
# Out:
#    Province  amount
# 1  เพชรบุรี      40
# 2   ราชบุรี       0

# %%
import pandas as pd

# %%
## กรณีกำหนด Index Label เป็นตัวเลข
numericIndexLabel_pd = pd.DataFrame({'Province':['กาญจนบุรี','เพชรบุรี','ราชบุรี']\
                                     ,'amount':[80,40,0]},index=[1,2,3])

# %%
numericIndexLabel_pd
# Out:
#     Province  amount
# 1  กาญจนบุรี      80
# 2   เพชรบุรี      40
# 3    ราชบุรี       0

# %%
# ตรวจสอบ index labels
print("Index Labels:", numericIndexLabel_pd.index)

# ตรวจสอบ index positions
print("Index Positions:", range(len(numericIndexLabel_pd)))
# Out:
# Index Labels: Int64Index([1, 2, 3], dtype='int64')
# Index Positions: range(0, 3)

# %%
numericIndexLabel_pd[1:]
# Out:
#    Province  amount
# 2  เพชรบุรี      40
# 3   ราชบุรี       0

# %%
import pandas as pd

# %%
## กรณีกำหนด Index Label เป็นตัวเลข
stringIndexLabel_pd = pd.DataFrame({'Province':['กาญจนบุรี','เพชรบุรี','ราชบุรี'],'amount':[80,40,0]}\
                                   ,index=['A','B','C'])

# %%
stringIndexLabel_pd
# Out:
#     Province  amount
# A  กาญจนบุรี      80
# B   เพชรบุรี      40
# C    ราชบุรี       0

# %%
# ตรวจสอบ index labels
print("Index Labels:", stringIndexLabel_pd.index)

# ตรวจสอบ index positions
print("Index Positions:", range(len(stringIndexLabel_pd)))
# Out:
# Index Labels: Index(['A', 'B', 'C'], dtype='object')
# Index Positions: range(0, 3)

# %%
stringIndexLabel_pd[1:]
# Out:
#    Province  amount
# B  เพชรบุรี      40
# C   ราชบุรี       0

# %%
stringIndexLabel_pd['A':]
# Out:
#     Province  amount
# A  กาญจนบุรี      80
# B   เพชรบุรี      40
# C    ราชบุรี       0
