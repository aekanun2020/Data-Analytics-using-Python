# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/Data-Analytics-using-Python/blob/main/E_Python_Pandas_Null_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create DataFrame with None/Null to work with examples
import pandas as pd
import numpy as np
technologies   = ({
    'Courses':["Spark","PySpark","Hadoop","Python","Pandas",None,"Spark","Python"],
    'Fee' :[22000,25000,23000,24000,np.nan,25000,25000,22000],
    'Duration':['30day','50days','55days','40days','60days','35day','','50days'],
    'Discount':[1000,2300,1000,1200,2500,1300,1400,1600]
          })
row_labels=['r0','r1','r2','r3','r4','r5','r6','r7']
df = pd.DataFrame(technologies, index=row_labels)
print(df)
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %%
df
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %% [markdown]
# **1. Null Summary**

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, r0 to r7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Courses   7 non-null      object
#  1   Fee       7 non-null      float64
#  2   Duration  8 non-null      object
#  3   Discount  8 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df.isnull().sum()
# Out:
# Courses     1
# Fee         1
# Duration    0
# Discount    0
# dtype: int64

# %%
type(df.isnull().sum())
# Out:
# pandas.core.series.Series

# %%
pd.DataFrame(df.isnull().sum())
# Out:
#           0
# Courses   1
# Fee       1
# Duration  0
# Discount  0

# %%
pd.DataFrame({'col_name':df.columns,'num_null':df.isnull().sum().values})
# Out:
#    col_name  num_null
# 0   Courses         1
# 1       Fee         1
# 2  Duration         0
# 3  Discount         0

# %% [markdown]
# **2. Locate Null**

# %%
df[df['Courses'].isnull()]
# Out:
#    Courses      Fee Duration  Discount
# r5    None  25000.0    35day      1300

# %%
df[df['Fee'].isnull()]
# Out:
#    Courses  Fee Duration  Discount
# r4  Pandas  NaN   60days      2500

# %%
df[df.columns[df.isnull().any()]]
# Out:
#     Courses      Fee
# r0    Spark  22000.0
# r1  PySpark  25000.0
# r2   Hadoop  23000.0
# r3   Python  24000.0
# r4   Pandas      NaN
# r5     None  25000.0
# r6    Spark  25000.0
# r7   Python  22000.0

# %%
df[df.isnull().any(axis=1)]
# Out:
#    Courses      Fee Duration  Discount
# r4  Pandas      NaN   60days      2500
# r5    None  25000.0    35day      1300

# %%
df[df.columns[df.isnull().any()]][df.isnull().any(axis=1)]
# Out:
#    Courses      Fee
# r4  Pandas      NaN
# r5    None  25000.0

# %%
df[df.isnull().any(axis=1)][df.columns[df.isnull().any()]]
# Out:
#    Courses      Fee
# r4  Pandas      NaN
# r5    None  25000.0

# %% [markdown]
# **TEST**

# %%
df[6:7][['Discount','Courses']]
# Out:
#     Discount Courses
# r6      1400   Spark

# %%
df[['Discount','Courses']][6:7]
# Out:
#     Discount Courses
# r6      1400   Spark
