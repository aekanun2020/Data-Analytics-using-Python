# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/Data-Analytics-using-Python/blob/main/Homework_Python_Pandas_CoeffVariation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
! wget https://storage.googleapis.com/5-7sep2022/data/2008.csv
# Out:
# --2022-09-15 08:34:08--  https://storage.googleapis.com/5-7sep2022/data/2008.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.199.128, 74.125.20.128, 74.125.135.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.199.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689413344 (657M) [text/csv]
# Saving to: ‘2008.csv’
#
# 2008.csv            100%[===================>] 657.48M   126MB/s    in 5.4s
#
# 2022-09-15 08:34:14 (122 MB/s) - ‘2008.csv’ saved [689413344/689413344]

# %%
! wc -l 2008.csv
# Out:
# 7009729 2008.csv

# %%
f = "2008.csv"
num_lines = sum(1 for l in open(f))
size = int(num_lines / 100)
import random
skip_idx = random.sample(range(1, num_lines), num_lines - size)
raw_pd = pd.read_csv(f, skiprows=skip_idx)

# %%
#raw_pd = pd.read_csv("2008.csv")

# %%
raw_pd.head(5)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   1039.0        1030   1133.0
# 1  2008      1           3          4   1210.0        1200   1905.0
# 2  2008      1           3          4   2015.0        1945   2101.0
# 3  2008      1           3          4   2104.0        2105   2315.0
# 4  2008      1           3          4   1727.0        1715   2012.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1140            WN       1244  ...    2.0      5.0          0
# 1        1850            WN        991  ...    6.0     28.0          0
# 2        2040            WN        725  ...    4.0      8.0          0
# 3        2330            WN       1915  ...    4.0      9.0          0
# 4        2000            WN        324  ...    4.0     11.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
raw_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70096 entries, 0 to 70095
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               70096 non-null  int64
#  1   Month              70096 non-null  int64
#  2   DayofMonth         70096 non-null  int64
#  3   DayOfWeek          70096 non-null  int64
#  4   DepTime            68752 non-null  float64
#  5   CRSDepTime         70096 non-null  int64
#  6   ArrTime            68605 non-null  float64
#  7   CRSArrTime         70096 non-null  int64
#  8   UniqueCarrier      70096 non-null  object
#  9   FlightNum          70096 non-null  int64
#  10  TailNum            69265 non-null  object
#  11  ActualElapsedTime  68569 non-null  float64
#  12  CRSElapsedTime     70092 non-null  float64
#  13  AirTime            68569 non-null  float64
#  14  ArrDelay           68569 non-null  float64
#  15  DepDelay           68752 non-null  float64
# ...

# %%
raw_pd.describe().transpose()
# Out:
#                      count         mean          std     min     25%     50%  \
# Year               70096.0  2008.000000     0.000000  2008.0  2008.0  2008.0
# Month              70096.0     6.389209     3.400993     1.0     3.0     6.0
# DayofMonth         70096.0    15.731754     8.774379     1.0     8.0    16.0
# DayOfWeek          70096.0     3.925645     1.992748     1.0     2.0     4.0
# DepTime            68752.0  1334.385632   479.616788     1.0   926.0  1326.0
# CRSDepTime         70096.0  1326.583585   465.501452     1.0   925.0  1320.0
# ArrTime            68605.0  1479.748429   507.771453     1.0  1103.0  1512.0
# CRSArrTime         70096.0  1494.439925   484.257052     0.0  1111.0  1518.0
# FlightNum          70096.0  2223.324555  1964.500072     1.0   616.0  1566.0
# ActualElapsedTime  68569.0   127.157754    69.881428    18.0    77.0   110.0
# CRSElapsedTime     70092.0   128.655724    69.043143     2.0    80.0   111.0
# ...

# %%
describe_pd = pd.DataFrame(raw_pd.describe().transpose())

# %%
describe_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, Year to LateAircraftDelay
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   24 non-null     float64
#  1   mean    24 non-null     float64
#  2   std     24 non-null     float64
#  3   min     24 non-null     float64
#  4   25%     24 non-null     float64
#  5   50%     24 non-null     float64
#  6   75%     24 non-null     float64
#  7   max     24 non-null     float64
# dtypes: float64(8)
# memory usage: 2.2+ KB
