# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/Data-Analytics-using-Python/blob/main/B_Python_Pandas_Dataframe_Basic_Properties_and_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Basic Properties**

# %%
# Create DataFrame with None/Null to work with examples
import pandas as pd
import numpy as np
technologies   = ({
    'Courses':["Spark","PySpark","Hadoop","Python","Pandas",None,"Spark","Python"],
    'Fee' :[22000,25000,23000,24000,np.nan,25000,25000,22000],
    'Duration':['30day','50days','55days','40days','60days','35day','','50days'],
    'Discount':[1000,2300,1000,1200,2500,1300,1400,1600]
          })
row_labels=['r0','r1','r2','r3','r4','r5','r6','r7']
df = pd.DataFrame(technologies, index=row_labels)
print(df)
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %%
df.shape
# Out:
# (8, 4)

# %%
df.size
# Out:
# 32

# %%
df.empty
# Out:
# False

# %%
df.columns
# Out:
# Index(['Courses', 'Fee', 'Duration', 'Discount'], dtype='object')

# %%
df.columns.values
# Out:
# array(['Courses', 'Fee', 'Duration', 'Discount'], dtype=object)

# %%
df.index
# Out:
# Index(['r0', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7'], dtype='object')

# %%
df.index.values
# Out:
# array(['r0', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7'], dtype=object)

# %%
df.dtypes
# Out:
# Courses      object
# Fee         float64
# Duration     object
# Discount      int64
# dtype: object

# %%
df.axes[0] # Display Index Label of Rows
# Out:
# Index(['r0', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7'], dtype='object')

# %%
df.axes[1] # Display Index Label of Columns
# Out:
# Index(['Courses', 'Fee', 'Duration', 'Discount'], dtype='object')

# %% [markdown]
# **2. Basic Methods of Filtering**

# %%
len(df.index)
# Out:
# 8

# %%
len(df.axes[0])
# Out:
# 8

# %%
len(df.axes[1])
# Out:
# 4

# %%
df.count()
# Out:
# Courses     7
# Fee         7
# Duration    8
# Discount    8
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, r0 to r7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Courses   7 non-null      object
#  1   Fee       7 non-null      float64
#  2   Duration  8 non-null      object
#  3   Discount  8 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 320.0+ bytes

# %% [markdown]
# **2.1 Basic Methods of Columns Filtering**

# %%
df['Fee'] # return Series
# Out:
# r0    22000.0
# r1    25000.0
# r2    23000.0
# r3    24000.0
# r4        NaN
# r5    25000.0
# r6    25000.0
# r7    22000.0
# Name: Fee, dtype: float64

# %%
df[['Fee']] # return Dataframe
# Out:
#         Fee
# r0  22000.0
# r1  25000.0
# r2  23000.0
# r3  24000.0
# r4      NaN
# r5  25000.0
# r6  25000.0
# r7  22000.0

# %%
df[df['Fee'] == 22000]
# Out:
#    Courses      Fee Duration  Discount
# r0   Spark  22000.0    30day      1000
# r7  Python  22000.0   50days      1600

# %%
df[['Fee']] - 500
# Out:
#         Fee
# r0  21500.0
# r1  24500.0
# r2  22500.0
# r3  23500.0
# r4      NaN
# r5  24500.0
# r6  24500.0
# r7  21500.0

# %%
df.apply(lambda x: x[df['Fee'] > 0])
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %%
df['Fee'].apply(lambda x: x if x >=0 else 0)
# Out:
# r0    22000.0
# r1    25000.0
# r2    23000.0
# r3    24000.0
# r4        0.0
# r5    25000.0
# r6    25000.0
# r7    22000.0
# Name: Fee, dtype: float64

# %% [markdown]
# **2.2 Basic Methods of Rows Filtering**

# %%
df[6:]
# Out:
#    Courses      Fee Duration  Discount
# r6   Spark  25000.0               1400
# r7  Python  22000.0   50days      1600

# %%
df[:6]
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300

# %%
df[6:6]
# Out:
# Empty DataFrame
# Columns: [Courses, Fee, Duration, Discount]
# Index: []

# %%
df[6:7]
# Out:
#    Courses      Fee Duration  Discount
# r6   Spark  25000.0               1400

# %%
df[:3]
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000

# %%
df[:-3]
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500

# %%
df[3:-3]
# Out:
#    Courses      Fee Duration  Discount
# r3  Python  24000.0   40days      1200
# r4  Pandas      NaN   60days      2500

# %%
df[:]['Discount'] # return Series
# Out:
# r0    1000
# r1    2300
# r2    1000
# r3    1200
# r4    2500
# r5    1300
# r6    1400
# r7    1600
# Name: Discount, dtype: int64

# %%
df[:][['Discount']] # return Dataframe
# Out:
#     Discount
# r0      1000
# r1      2300
# r2      1000
# r3      1200
# r4      2500
# r5      1300
# r6      1400
# r7      1600

# %%
df[6:7][['Discount']]
# Out:
#     Discount
# r6      1400

# %%
df[6:7][['Discount','Courses']]
# Out:
#     Discount Courses
# r6      1400   Spark

# %% [markdown]
# **Basic Methods for Creating a New Column**

# %%
df
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %%
df[['Special_Price']] = df[['Fee']] - 500
df
# Out:
#     Courses      Fee Duration  Discount  Special_Price
# r0    Spark  22000.0    30day      1000        21500.0
# r1  PySpark  25000.0   50days      2300        24500.0
# r2   Hadoop  23000.0   55days      1000        22500.0
# r3   Python  24000.0   40days      1200        23500.0
# r4   Pandas      NaN   60days      2500            NaN
# r5     None  25000.0    35day      1300        24500.0
# r6    Spark  25000.0               1400        24500.0
# r7   Python  22000.0   50days      1600        21500.0

# %% [markdown]
# **Basic Methods for Modifying a Existing Column**

# %%
df[['Special_Price']] = df[['Special_Price']] + 500
df
# Out:
#     Courses      Fee Duration  Discount  Special_Price
# r0    Spark  22000.0    30day      1000        22000.0
# r1  PySpark  25000.0   50days      2300        25000.0
# r2   Hadoop  23000.0   55days      1000        23000.0
# r3   Python  24000.0   40days      1200        24000.0
# r4   Pandas      NaN   60days      2500            NaN
# r5     None  25000.0    35day      1300        25000.0
# r6    Spark  25000.0               1400        25000.0
# r7   Python  22000.0   50days      1600        22000.0

# %% [markdown]
# **TEST**

# %%
df[['Fee','Special_Price']]
# Out:
#         Fee  Special_Price
# r0  22000.0        22000.0
# r1  25000.0        25000.0
# r2  23000.0        23000.0
# r3  24000.0        24000.0
# r4      NaN            NaN
# r5  25000.0        25000.0
# r6  25000.0        25000.0
# r7  22000.0        22000.0

# %%
df['r3':'r5']
# Out:
#    Courses      Fee Duration  Discount  Special_Price
# r3  Python  24000.0   40days      1200        24000.0
# r4  Pandas      NaN   60days      2500            NaN
# r5    None  25000.0    35day      1300        25000.0

# %%
df['r3':]
# Out:
#    Courses      Fee Duration  Discount  Special_Price
# r3  Python  24000.0   40days      1200        24000.0
# r4  Pandas      NaN   60days      2500            NaN
# r5    None  25000.0    35day      1300        25000.0
# r6   Spark  25000.0               1400        25000.0
# r7  Python  22000.0   50days      1600        22000.0

# %%
test_pd = pd.DataFrame({'Province':['กาญจนบุรี','เพชรบุรี','ราชบุรี','กรุงเทพ','สมุทรสงคราม']\
                        ,'Lastname':[80,60,0,100,40]},index=['1','2','3','4','5'])

# %%
test_pd
# Out:
#       Province  Lastname
# 1    กาญจนบุรี        80
# 2     เพชรบุรี        60
# 3      ราชบุรี         0
# 4      กรุงเทพ       100
# 5  สมุทรสงคราม        40

# %%
test_pd[1:]
# Out:
#       Province  Lastname
# 2     เพชรบุรี        60
# 3      ราชบุรี         0
# 4      กรุงเทพ       100
# 5  สมุทรสงคราม        40

# %%
test_pd['1':]
# Out:
#       Province  Lastname
# 1    กาญจนบุรี        80
# 2     เพชรบุรี        60
# 3      ราชบุรี         0
# 4      กรุงเทพ       100
# 5  สมุทรสงคราม        40

# %%
test_pd[1:1]
# Out:
# Empty DataFrame
# Columns: [Province, Lastname]
# Index: []

# %%
test_pd[2:2]
# Out:
# Empty DataFrame
# Columns: [Province, Lastname]
# Index: []

# %%
test_pd[4:4]
# Out:
# Empty DataFrame
# Columns: [Province, Lastname]
# Index: []

# %%
test_pd[2:6]
# Out:
#       Province  Lastname
# 3      ราชบุรี         0
# 4      กรุงเทพ       100
# 5  สมุทรสงคราม        40

# %%
test_pd[:1000]
# Out:
#       Province  Lastname
# 1    กาญจนบุรี        80
# 2     เพชรบุรี        60
# 3      ราชบุรี         0
# 4      กรุงเทพ       100
# 5  สมุทรสงคราม        40

# %%
noDefineIndexLabel_pd = pd.DataFrame({'Province':['กาญจนบุรี','เพชรบุรี','ราชบุรี','กรุงเทพ','สมุทรสงคราม']\
                        ,'Lastname':[80,60,0,100,40]})

# %%
noDefineIndexLabel_pd
# Out:
#       Province  Lastname
# 0    กาญจนบุรี        80
# 1     เพชรบุรี        60
# 2      ราชบุรี         0
# 3      กรุงเทพ       100
# 4  สมุทรสงคราม        40

# %%
noDefineIndexLabel_pd[1:1]
# Out:
# Empty DataFrame
# Columns: [Province, Lastname]
# Index: []

# %%
noDefineIndexLabel_pd[2:2]
# Out:
# Empty DataFrame
# Columns: [Province, Lastname]
# Index: []

# %%
noDefineIndexLabel_pd[4:4]
# Out:
# Empty DataFrame
# Columns: [Province, Lastname]
# Index: []

# %%
noDefineIndexLabel_pd[2:6]
# Out:
#       Province  Lastname
# 2      ราชบุรี         0
# 3      กรุงเทพ       100
# 4  สมุทรสงคราม        40

# %%
df
# Out:
#     Courses      Fee Duration  Discount  Special_Price
# r0    Spark  22000.0    30day      1000        22000.0
# r1  PySpark  25000.0   50days      2300        25000.0
# r2   Hadoop  23000.0   55days      1000        23000.0
# r3   Python  24000.0   40days      1200        24000.0
# r4   Pandas      NaN   60days      2500            NaN
# r5     None  25000.0    35day      1300        25000.0
# r6    Spark  25000.0               1400        25000.0
# r7   Python  22000.0   50days      1600        22000.0

# %%
df[:][['Fee','Special_Price']]
# Out:
#         Fee  Special_Price
# r0  22000.0        22000.0
# r1  25000.0        25000.0
# r2  23000.0        23000.0
# r3  24000.0        24000.0
# r4      NaN            NaN
# r5  25000.0        25000.0
# r6  25000.0        25000.0
# r7  22000.0        22000.0

# %%
df['r0':'r4']
# Out:
#     Courses      Fee Duration  Discount  Special_Price
# r0    Spark  22000.0    30day      1000        22000.0
# r1  PySpark  25000.0   50days      2300        25000.0
# r2   Hadoop  23000.0   55days      1000        23000.0
# r3   Python  24000.0   40days      1200        24000.0
# r4   Pandas      NaN   60days      2500            NaN

# %%
## จำเป็นต้องใช้ .loc[] เนื่องจาก df[] อาจไม่สามารถระบุ row index label แบบกระโดดได้
df.loc[['r0','r3','r7']]
# Out:
#    Courses      Fee Duration  Discount  Special_Price
# r0   Spark  22000.0    30day      1000        22000.0
# r3  Python  24000.0   40days      1200        24000.0
# r7  Python  22000.0   50days      1600        22000.0

# %%
## จำเป็นต้องใช้ .loc[] เนื่องจาก df[] อาจไม่สามารถตัดออกมาเพียง Single row ด้วย row index label ได้
df.loc[['r5']]
# Out:
#    Courses      Fee Duration  Discount  Special_Price
# r5    None  25000.0    35day      1300        25000.0
